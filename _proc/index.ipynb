# %% [raw]
# ---
# description: Canvas Grouping Python Script
# output-file: index.html
# title: CanvasGroupy
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This module will use `GroupEng` to create canvas and github groups.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install CanvasGroupy
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Please visit [GroupEng Official Website](https://groupeng.org/) to see the documnetation of how to use GroupEng.

# %%
assign_groups("example/sample_group_specification.groupeng")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 assign_groups("example/sample_group_specification.groupeng")
#
# File ~/Desktop/SP23_Working/Group_Eng/CanvasGroupy/CanvasGroupy/assign.py:9, in assign_groups(groupeng_config)
#       7 def assign_groups(groupeng_config:str # Directory for the GroupEng config yml file
#       8                  ) -> (bool, str): # Status and output directory of the compile file.
# ----> 9     status, outdir = GroupEng.run(groupeng_config)
#      10     return status, outdir
#
# NameError: name 'GroupEng' is not defined
