# %% [raw]
# ---
# description: Examples of a workflow of creating canvas groups.
# output-file: canvas_group_example.html
# title: Canvas Group Example
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from CanvasGroupy import gh_group, canvas
import json

# %%
credentials_fp = "../credentials.json"

gh = gh_group.GitHubGroup(credentials_fp)

API_URL = "https://canvas.ucsd.edu/"
canvas = canvas.CanvasGroup(credentials_fp, API_URL)

# %%
for i in range(45):
    unsuccessful = cg.assign_canvas_group(
        group_name=f"Group{i:03}-SP23", 
        group_members=[], 
        in_group_category="Final Project"
    )

# %%
# the following code get a list of unreasonable github username
g = Github(credentials["GitHub Token"])

unsuccessful = dict()

for email, username in out_dict['GitHub ID'].items():
    try:
        g.get_user(username)
    except Exception as e:
        print(f"User: {bcolors.WARNING+username+bcolors.ENDC} Not Found on GitHub")
        unsuccessful[email] = username
unsuccessful
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # the following code get a list of unreasonable github username
# ----> 2 g = Github(credentials["GitHub Token"])
#       4 unsuccessful = dict()
#       6 for email, username in out_dict['GitHub ID'].items():
#
# NameError: name 'Github' is not defined
